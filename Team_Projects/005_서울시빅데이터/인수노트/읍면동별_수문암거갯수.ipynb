# %%
import pandas as pd

# %%
#pd.read_csv("./제방암거수문개수.csv")

# %%
제방=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\가공된데이터\암거.csv")

# %%
암거=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\가공된데이터\암거.csv")

# %%
암거
# Out:
#                                     UFID      SCLS      FMTA  OBJECTID_1  \
# 0      100037612004C007135e124d8f9c94482  C0076116  S2111464         272
# 1      100037612004C00710ec30fee091c4f4c  C0076116  S2111464         272
# 2      100037612005C0071ed51917ba5fa4849  C0076116  S2114693         268
# 3      100037612005C007113a3f3c3c8b44ae3  C0076116  S2114693         268
# 4      100037612008C0071b30d8c3a6ab444ce  C0076116  S2114693         308
# ...                                  ...       ...       ...         ...
# 23328  100037705083C007103bf63e26ad5493c  C0076117  S2118886          80
# 23329  100037705083C0071ac9b5319475f4ea8  C0076117  S2118886          79
# 23330  100037705061C0071ee7e8e1719e34e0d  C0076117  S2118886         127
# 23331  100037705061C00710f82f01705c84fb7  C0076117  S2118886         127
# 23332  100037705071C007165e2c6202acb442c  C0076117  S2118886          23
#
#        OBJECTID  BASE_YEAR   ADM_CD ADM_NM    Shape_Area  GU_CODE GU_NAME  \
# ...
