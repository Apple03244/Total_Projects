# %%
import pandas as pd
import os
file_names=[x for x in os.listdir("./") if "csv" in x]
file_names=[x for x in file_names if "위경도" not in x]

# %%
data_set={}
for file in file_names:
    data_set[file]=pd.read_csv(f"./{file}")

# %%
file_names
# Out:
# ['동별_인구_고도_배수등급_공시지가_결합.csv',
#  '수문.csv',
#  '실폭하천.csv',
#  '암거.csv',
#  '자원공원용도지구.csv',
#  '재해위험지구_경계도.csv',
#  '제방.csv',
#  '침수흔적도.csv']

# %% [markdown]
# ## 데이터 Nan값

# %% [markdown]
# ### 1. 동별 인구 고도 배수등급

# %%
data_set[file_names[0]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96891 entries, 0 to 96890
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   field_1                96891 non-null  int64
#  1   AREA                   96891 non-null  float64
#  2   PERIMETER              96891 non-null  float64
#  3   ELEVATION              96891 non-null  float64
#  4   AREA_2                 96891 non-null  float64
#  5   PERIMETER_2            96891 non-null  float64
#  6   CODE_DC                96891 non-null  float64
#  7   SOILDRA                96891 non-null  object
#  8   OBJECTID_1             96891 non-null  int64
#  9   OBJECTID               96891 non-null  float64
#  10  BASE_YEAR              96891 non-null  int64
#  11  ADM_CD                 96891 non-null  int64
#  12  ADM_NM                 96891 non-null  object
#  13  Shape_Area             96891 non-null  float64
# ...

# %% [markdown]
# 공시지가 2019년 평균

# %%
data_1=data_set[file_names[0]]

# %%
ADM_NA=set(data_1[data_1["공시지가_2019평균_공시지가(원/㎡)"].isna()]["ADM_NM"].unique()) #NAN값 행정동명
ADM_2017=set(pd.read_excel("./공시지가_2017평균.xlsx")["법정동명"].unique()) #각 년도별 공시지가를 가진 행정동명
ADM_2018=set(pd.read_excel("./공시지가_2018평균.xlsx")["법정동명"].unique())

# %% [markdown]
# Na 공시지가 지역, 2017,2018, 처리하고 난 후의 행정동명 개수 변화

# %%
print(len(ADM_NA),len(ADM_2017),len(ADM_2018),len((ADM_NA-ADM_2017)-ADM_2018))
# Out:
# 331 465 465 331

# %% [markdown]
# * 공시지가 NA값을 그대로 둔채 일단 진행

# %% [markdown]
# ## 비고 추가

# %%
for i in range(len(file_names)):
    data_set[file_names[i]]["비고"]=file_names[i]

# %% [markdown]
# ---------

# %%
check=list(data_set[file_names[0]]["ADM_NM"].unique())

# %% [markdown]
# ### 2. 수문

# %%
data_set[file_names[1]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851 entries, 0 to 850
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UFID        851 non-null    object
#  1   DIVI        851 non-null    object
#  2   QUAL        851 non-null    object
#  3   SCLS        851 non-null    object
#  4   FMTA        851 non-null    object
#  5   OBJECTID_1  851 non-null    int64
#  6   OBJECTID    851 non-null    float64
#  7   BASE_YEAR   851 non-null    int64
#  8   ADM_CD      851 non-null    int64
#  9   ADM_NM      851 non-null    object
#  10  Shape_Area  851 non-null    float64
#  11  GU_CODE     851 non-null    int64
#  12  GU_NAME     851 non-null    object
#  13  POP         851 non-null    int64
#  14  비고          851 non-null    object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 99.9+ KB

# %% [markdown]
# - NAN 값 없음

# %%
data_set[file_names[1]]["비고"]=file_names[1]

# %%
data_set[file_names[1]].head(3)
# Out:
#                                 UFID    DIVI    QUAL      SCLS      FMTA  \
# 0  100037612004C006184642d37557b45df  SUD001  SUQ000  C0062241  S2117964
# 1  100037709007C0061a755e376fd8e4145  SUD001  SUQ000  C0062241  S2117964
# 2  100037709015C0061b5ec725f7ec74170  SUD001  SUQ000  C0062241  S2117964
#
#    OBJECTID_1  OBJECTID  BASE_YEAR   ADM_CD ADM_NM    Shape_Area  GU_CODE  \
# 0         271     271.0       2016  1117068   오류2동  4.504714e+06    11530
# 1         384     384.0       2016  1124055   마천1동  5.748087e+05    11710
# 2         375     375.0       2016  1123076    세곡동  6.362857e+06    11680
#
#   GU_NAME    POP      비고
# 0     구로구  49302  수문.csv
# 1     송파구  21004  수문.csv
# 2     강남구  45180  수문.csv

# %% [markdown]
# ### 3. 실폭하천

# %%
data_set[file_names[2]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UFID        460 non-null    object
#  1   SCLS        460 non-null    object
#  2   FMTA        460 non-null    object
#  3   OBJECTID_1  460 non-null    int64
#  4   OBJECTID    460 non-null    float64
#  5   BASE_YEAR   460 non-null    int64
#  6   ADM_CD      460 non-null    int64
#  7   ADM_NM      460 non-null    object
#  8   Shape_Area  460 non-null    float64
#  9   GU_CODE     460 non-null    int64
#  10  GU_NAME     460 non-null    object
#  11  POP         460 non-null    int64
#  12  비고          460 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 46.8+ KB

# %% [markdown]
# - NAN 값 없음

# %%
data_set[file_names[2]].head(3)
# Out:
#                                 UFID      SCLS      FMTA  OBJECTID_1  \
# 0  100037612007E00312875890709eb4d6a  E0032111  S2115489         263
# 1  100037612007E00312875890709eb4d6a  E0032111  S2115489         264
# 2  100037612007E00312875890709eb4d6a  E0032111  S2115489         265
#
#    OBJECTID  BASE_YEAR   ADM_CD ADM_NM    Shape_Area  GU_CODE GU_NAME    POP  \
# 0     263.0       2016  1117054   구로3동  1.039352e+06    11530     구로구  26579
# 1     264.0       2016  1117055   구로4동  5.241234e+05    11530     구로구  26721
# 2     265.0       2016  1117056   구로5동  1.011733e+06    11530     구로구  33800
#
#          비고
# 0  실폭하천.csv
# 1  실폭하천.csv
# 2  실폭하천.csv

# %% [markdown]
# ### 4. 암거

# %%
data_set[file_names[3]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23333 entries, 0 to 23332
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UFID        23333 non-null  object
#  1   SCLS        23333 non-null  object
#  2   FMTA        23333 non-null  object
#  3   OBJECTID_1  23333 non-null  int64
#  4   OBJECTID    23333 non-null  float64
#  5   BASE_YEAR   23333 non-null  int64
#  6   ADM_CD      23333 non-null  int64
#  7   ADM_NM      23333 non-null  object
#  8   Shape_Area  23333 non-null  float64
#  9   GU_CODE     23333 non-null  int64
#  10  GU_NAME     23333 non-null  object
#  11  POP         23333 non-null  int64
#  12  비고          23333 non-null  object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# - NAN값 없음

# %% [markdown]
# ### 5. 자원공원용지구

# %%
data_set[file_names[4]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ALIAS       24 non-null     object
#  1   REMARK      3 non-null      object
#  2   NTFDATE     0 non-null      float64
#  3   SGG_OID     105 non-null    int64
#  4   COL_ADM_SE  105 non-null    int64
#  5   MNUM        105 non-null    object
#  6   OBJECTID_1  105 non-null    int64
#  7   OBJECTID    105 non-null    float64
#  8   BASE_YEAR   105 non-null    int64
#  9   ADM_CD      105 non-null    int64
#  10  ADM_NM      105 non-null    object
#  11  Shape_Area  105 non-null    float64
#  12  GU_CODE     105 non-null    int64
#  13  GU_NAME     105 non-null    object
#  14  POP         105 non-null    int64
#  15  비고          105 non-null    object
# dtypes: float64(3), int64(7), object(6)
# memory usage: 13.3+ KB

# %%
data_set[file_names[4]]
# Out:
#       ALIAS REMARK  NTFDATE  SGG_OID  COL_ADM_SE  \
# 0       NaN    NaN      NaN       65       11110
# 1       NaN    NaN      NaN       65       11110
# 2       NaN    NaN      NaN       49       11110
# 3       NaN    NaN      NaN       50       11110
# 4       NaN    NaN      NaN       51       11110
# ..      ...    ...      ...      ...         ...
# 100  자연보존지구    NaN      NaN      357       11410
# 101  자연보존지구    NaN      NaN      358       11410
# 102     NaN    NaN      NaN      359       11410
# 103     NaN    NaN      NaN      359       11410
# 104     NaN    NaN      NaN      359       11410
#
#                                   MNUM  OBJECTID_1  OBJECTID  BASE_YEAR  \
# 0    14800001111020120001UMB2000001001           4       4.0       2016
# 1    14800001111020120001UMB2000001001         117     117.0       2016
# 2    14800001111020110002UMB2000001001           4       4.0       2016
# 3    14800001111020110003UMB2000001001           4       4.0       2016
# ...

# %% [markdown]
# 이건 당연히 NAN값이 있을수밖에..

# %% [markdown]
# ### 6. 재해위험지구 경계

# %%
data_set[file_names[5]]
# Out:
#                                  MNUM  ALIAS  REMARK  NTFDATE    SHAPE_AREA  \
# 0   30000001111020120001UPB2000001001    NaN     NaN      NaN  3.227360e+03
# 1   30200001117020110013UPB2100001005    NaN     NaN      NaN  1.805315e+05
# 2   30200001117020110013UPB2100001005    NaN     NaN      NaN  1.805315e+05
# 3   30200001117020110013UPB2100001005    NaN     NaN      NaN  1.805315e+05
# 4   30200001117020110013UPB2100001005    NaN     NaN      NaN  1.805315e+05
# 5   31400001147020110000UPB2100002001    NaN     NaN      NaN  9.966881e+03
# 6   31400001147020110000UPB2100002001    NaN     NaN      NaN  9.966881e+03
# 7   31400001147020110000UPB2100001001    NaN     NaN      NaN  1.335794e+05
# 8   31400001147020110000UPB2100001001    NaN     NaN      NaN  1.335794e+05
# 9   31400001147020110000UPB2100001001    NaN     NaN      NaN  1.335794e+05
# 10  31400001147020110000UPB2100001001    NaN     NaN      NaN  1.335794e+05
# ...

# %% [markdown]
# ### 7. 제방

# %%
data_set[file_names[6]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7457 entries, 0 to 7456
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UFID        7457 non-null   object
#  1   NAME        0 non-null      float64
#  2   DIVI        7457 non-null   object
#  3   QUAL        7457 non-null   object
#  4   UDDI        7457 non-null   object
#  5   LENG        7457 non-null   float64
#  6   HEIG        7457 non-null   float64
#  7   SCLS        7457 non-null   object
#  8   FMTA        7457 non-null   object
#  9   OBJECTID_1  7457 non-null   int64
#  10  OBJECTID    7457 non-null   float64
#  11  BASE_YEAR   7457 non-null   int64
#  12  ADM_CD      7457 non-null   int64
#  13  ADM_NM      7457 non-null   object
#  14  Shape_Area  7457 non-null   float64
#  15  GU_CODE     7457 non-null   int64
#  16  GU_NAME     7457 non-null   object
#  17  POP         7457 non-null   int64
#  18  비고          7457 non-null   object
# ...

# %% [markdown]
# ### 8. 침수흔적도

# %%
data_set[file_names[7]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8887 entries, 0 to 8886
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    5075 non-null   float64
#  1   GU_NAM      8887 non-null   object
#  2   F_SHIM      8887 non-null   float64
#  3   F_DISA_NM   8887 non-null   object
#  4   F_AVR_HGT   8887 non-null   float64
#  5   F_AREA      8887 non-null   float64
#  6   ADM_CD      8887 non-null   int64
#  7   F_SAT_YMD   8887 non-null   object
#  8   F_END_YMD   8887 non-null   object
#  9   F_SAT_TM    8887 non-null   int64
#  10  F_END_TM    8887 non-null   int64
#  11  F_RSN_DTL   8887 non-null   object
#  12  F_ZONE_NM   8887 non-null   object
#  13  INV_YR      8887 non-null   int64
#  14  F_YR        8887 non-null   int64
#  15  TYPE        8887 non-null   object
#  16  OBJECTID_1  8887 non-null   int64
#  17  OBJECTID_2  8887 non-null   float64
#  18  BASE_YEAR   8887 non-null   int64
# ...

# %%
data_set[file_names[7]]
# Out:
#       OBJECTID GU_NAM  F_SHIM          F_DISA_NM  F_AVR_HGT    F_AREA  \
# 0        275.0    강북구    0.02  2022년 8.8 ~17. 호우     114.53   3876.00
# 1        223.0    강북구    0.02  2022년 8.8 ~17. 호우     118.05   2188.00
# 2        246.0    강북구    0.02  2022년 8.8 ~17. 호우     129.55  45287.00
# 3       4253.0   영등포구    0.30  2022년 8.8 ~17. 호우      10.18     53.00
# 4        301.0    강북구    0.02  2022년 8.8 ~17. 호우      75.48    105.00
# ...        ...    ...     ...                ...        ...       ...
# 8882      42.0    용산구    0.10  2022년 8.8 ~17. 호우      14.38    151.71
# 8883      59.0    용산구    0.10  2022년 8.8 ~17. 호우      56.60     74.09
# 8884      45.0    용산구    0.10  2022년 8.8 ~17. 호우      17.31    190.53
# 8885     116.0    성북구    0.10  2022년 8.8 ~17. 호우      84.05     33.97
# 8886     617.0   서대문구    0.10  2022년 8.8 ~17. 호우      13.74    161.86
#
#           ADM_CD F_SAT_YMD F_END_YMD  F_SAT_TM  ...  OBJECTID_1 OBJECTID_2  \
# ...

# %% [markdown]
# --------

# %% [markdown]
# # 데이터 Merge
# > 비고  : 원본 data 파일명을 넣어놔야 안헷갈릴 듯

# %% [markdown]
# ## 1. 좌표 : MUNM

# %%
mnum_datas=pd.concat([data_set[file_names[4]],data_set[file_names[5]]])

# %%
mnum_datas.to_csv("./mnum_data.csv")

# %% [markdown]
# 위도경도로 바꾸는 API 찾아서 처리해야함

# %% [markdown]
# ## 2. 좌표 : UFID
# 2347

# %%
ufid_datas=pd.concat([data_set[file_names[1]],data_set[file_names[2]]
                      ,data_set[file_names[3]],data_set[file_names[6]]])

# %%
ufid_datas.to_csv("./ufid_data.csv")

# %% [markdown]
# ## 위경도

# %%
'F_ZONE_NM'
# Out:
# 'F_ZONE_NM'

# %%
data_set[file_names[7]]
# Out:
#       OBJECTID GU_NAM  F_SHIM          F_DISA_NM  F_AVR_HGT    F_AREA  \
# 0        275.0    강북구    0.02  2022년 8.8 ~17. 호우     114.53   3876.00
# 1        223.0    강북구    0.02  2022년 8.8 ~17. 호우     118.05   2188.00
# 2        246.0    강북구    0.02  2022년 8.8 ~17. 호우     129.55  45287.00
# 3       4253.0   영등포구    0.30  2022년 8.8 ~17. 호우      10.18     53.00
# 4        301.0    강북구    0.02  2022년 8.8 ~17. 호우      75.48    105.00
# ...        ...    ...     ...                ...        ...       ...
# 8882      42.0    용산구    0.10  2022년 8.8 ~17. 호우      14.38    151.71
# 8883      59.0    용산구    0.10  2022년 8.8 ~17. 호우      56.60     74.09
# 8884      45.0    용산구    0.10  2022년 8.8 ~17. 호우      17.31    190.53
# 8885     116.0    성북구    0.10  2022년 8.8 ~17. 호우      84.05     33.97
# 8886     617.0   서대문구    0.10  2022년 8.8 ~17. 호우      13.74    161.86
#
#           ADM_CD F_SAT_YMD F_END_YMD  F_SAT_TM  ...  OBJECTID_1 OBJECTID_2  \
# ...

# %%
addrs_list=list(data_set[file_names[7]]["F_ZONE_NM"].values)

# %% [markdown]
# 위경도를 좌표로 바꾸기

# %% [markdown]
# --------

# %% [markdown]
# 카카오 API

# %%
import json
import requests as rq
def getAddr(addrs):
    REST_API_KEY='4fd65a1fc1d9de84fb9809d081f3fc8c'
    headers = {"Authorization": f"KakaoAK {REST_API_KEY}"}
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+addrs+"&analyze_type=exact"
    model=rq.get(url,headers=headers)
    if model.status_code!=200:
        return addrs
    else:
        return json.loads(str(rq.get(url,headers=headers).text))['documents']

# %% [markdown]
# 첫번째 검색 결과가 정확하게 나오지 않을수있으니 확인요망
# 아쉽지만 한번더 전처리 해야함

# %% [markdown]
# ------

# %%
import tqdm
num_list=list(range(0,len(addrs_list),200))

# %%
pd.DataFrame(columns=["경도","위도","주소"]).to_csv("./위경도데이터.csv")

# %%
def makexy(i,j):
    with tqdm.tqdm(total=j-i,unit="B",unit_scale=True) as process_bar:
        for addrs in addrs_list[i:j]:
            temp=getAddr(addrs)
            try:
                xy_data=[{'경도':temp[0]["x"],"위도":temp[0]["x"],'주소':temp[0]['address_name']}]
                merge_data=pd.DataFrame(xy_data)
                merged_data=pd.read_csv("./위경도데이터.csv")
                add_xy_data=pd.concat([merged_data,merge_data])
                add_xy_data[["경도","위도","주소"]].to_csv("./위경도데이터.csv")
            except:
                continue
            process_bar.update(1)

# %%
makexy(8000,8860)
# Out:
#   0%|          | 0.00/860 [00:00<?, ?B/s]

# %%
pd.read_csv("./위경도데이터.csv")
# Out:
#       Unnamed: 0          경도          위도                   주소
# 0              0  127.006585  127.006585     서울 강북구 우이동 296-1
# 1              1  127.007293  127.007293     서울 강북구 우이동 299-2
# 2              2  127.006001  127.006001    서울 강북구 우이동 산 8-15
# 3              3  126.909863  126.909863  서울 영등포구 영등포동3가 13-7
# 4              4  127.033223  127.033223   서울 강북구 미아동 258-241
# ...          ...         ...         ...                  ...
# 6599        6599  126.952165  126.952165           서울 관악구 봉천동
# 6600        6600  126.927124  126.927124           서울 관악구 신림동
# 6601        6601  126.927124  126.927124           서울 관악구 신림동
# 6602        6602  126.927124  126.927124           서울 관악구 신림동
# 6603           0  126.952165  126.952165           서울 관악구 봉천동
#
# [6604 rows x 4 columns]

# %%
pd.read_csv("./위경도데이터.csv")
# Out:
#     Unnamed: 0          경도          위도                   주소
# 0            0  127.006585  127.006585     서울 강북구 우이동 296-1
# 1            1  127.007293  127.007293     서울 강북구 우이동 299-2
# 2            2  127.006001  127.006001    서울 강북구 우이동 산 8-15
# 3            3  126.909863  126.909863  서울 영등포구 영등포동3가 13-7
# 4            4  127.033223  127.033223   서울 강북구 미아동 258-241
# ..         ...         ...         ...                  ...
# 94          94  126.902842  126.902842  서울 영등포구 신길동 355-318
# 95          95  126.902824  126.902824  서울 영등포구 신길동 355-279
# 96          96  126.902842  126.902842  서울 영등포구 신길동 355-302
# 97          97  126.902547  126.902547  서울 영등포구 신길동 355-243
# 98           0  126.902423  126.902423  서울 영등포구 신길동 355-176
#
# [99 rows x 4 columns]

# %%
pd.read_csv("./위경도데이터.csv")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 경도, 위도, 주소]
# Index: []

# %% [markdown]
# ----------임시-------------

# %%
result={"success":[],"false":[]}
with tqdm.tqdm(total=200,unit="B",unit_scale=True) as process_bar:
    for addrs in addrs_list[:200]:
        temp=getAddr(addrs)
        if (result==addrs) or (result==[]):
            result["false"].append(addrs)
        else:
            result["success"].append(temp)
        process_bar.update(1)
# Out:
# 100%|██████████| 200/200 [11:19<00:00, 3.40s/B]

# %%
useful_datas=[{'경도':x[0]["x"],"위도":x[0]["x"],'주소':x[0]['address_name']} for x in result["success"] if x]
merge_data=pd.DataFrame(useful_datas)
merge_data["주소"]=merge_data["주소"].apply(lambda x: x.replace("서울","서울특별시"))

# %%
add_xy_data=pd.merge(data_set[file_names[7]],merge_data,left_on='F_ZONE_NM',right_on="주소",how="left")

# %%
add_xy_data.to_csv("./위경도_추가_데이터.csv")

# %% [markdown]
# 왜 안되지...

# %%
pd.DataFrame(columns=["경도","위도","주소"]).to_csv("./위경도데이터.csv")

# %%
pd.read_csv("./위경도데이터.csv")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 경도, 위도, 주소]
# Index: []

# %%
xy_data=getAddr("김포시태장로845")

# %%
xy_data[0]["address_name"]
# Out:
# '경기 김포시 태장로 845'

# %%
def need_funtion(i,j):
    result={"success":[],"false":[]}
    with tqdm.tqdm(total=j-i,unit="B",unit_scale=True) as process_bar:
        for addrs in addrs_list[i:j]:
            temp=getAddr(addrs)
            if (result==addrs) or (result==[]):
                result["false"].append(addrs)
            else:
                result["success"].append(temp)
            process_bar.update(1)
    useful_datas=[{'경도':x[0]["x"],"위도":x[0]["x"],'주소':x[0]['address_name']} for x in result["success"] if x]
    merge_data=pd.DataFrame(useful_datas)
    merge_data["주소"]=merge_data["주소"].apply(lambda x: x.replace("서울","서울특별시"))
    add_xy_data=pd.merge(pd.read_csv("./위경도_추가_데이터.csv"),merge_data,left_on='F_ZONE_NM',right_on="주소",how="left")
    add_xy_data.to_csv("./위경도_추가_데이터.csv")
    print(f'{i}~{j}까지 완료')

# %%
need_funtion(200,400)
# Out:
# 100%|██████████| 200/200 [10:35<00:00, 3.18s/B]
# 200~400까지 완료

# %%
test=pd.read_csv("./위경도_추가_데이터.csv")

# %%
test[200:400]
# Out:
#      Unnamed: 0.1  Unnamed: 0  OBJECTID GU_NAM  F_SHIM  \
# 200           200         200     110.0    중랑구    0.01
# 201           201         201     103.0    중랑구    0.01
# 202           202         202      89.0    중랑구    0.02
# 203           203         203      97.0    중랑구    0.01
# 204           204         204      93.0    중랑구    0.01
# ..            ...         ...       ...    ...     ...
# 395           395         393    4409.0   영등포구    0.30
# 396           396         394    4410.0   영등포구    0.30
# 397           397         395    1998.0   영등포구    0.30
# 398           398         396    1999.0   영등포구    0.30
# 399           399         397    2000.0   영등포구    0.30
#
#                     F_DISA_NM  F_AVR_HGT  F_AREA      ADM_CD F_SAT_YMD  ...  \
# 200  2022년 9.3~7. 제11호 태풍 힌남노       19.0   55.88  1126010100  20220905  ...
# 201         2022년 8.8 ~17. 호우       28.0   58.50  1126010100  20220815  ...
# ...

# %%
서울시=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\서울시 읍면동마스터 정보.csv",encoding="euc-kr")

# %%
fact=set(서울시[서울시["시도_명칭"]=="서울"]["행정동_명칭"].unique())

# %%
fact-set(check)
# Out:
# {'금호2,3가동',
#  '돈암1동',
#  '돈암2동',
#  '동선동',
#  '면목3,8동',
#  '상계3,4동',
#  '상계6,7동',
#  '정릉2동',
#  '종로1,2,3,4가동',
#  '종로5,6가동',
#  '중계2,3동'}

# %%
set(check)-fact
# Out:
# {'금호2·3가동', '면목3·8동', '상계3·4동', '상계6·7동', '종로1·2·3·4가동', '종로5·6가동', '중계2·3동'}

# %%
len(check)
# Out:
# 419

# %%
len(fact)
# Out:
# 423
