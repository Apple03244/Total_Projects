# %%
import pandas as pd

# %%
기초수급자=pd.read_csv("./국민기초생활보장+연령별+일반수급자(구별)_20231003143933.csv")
주민등록=pd.read_csv("./주민등록연앙인구(연령별)_20231003144338.csv")
장애인=pd.read_csv("./장애인+현황(장애유형별_동별)_20231003144226.csv")

# %%
기초수급자
# Out:
#        시점  자치구별(1)  자치구별(2)   일반수급자 일반수급자.1 일반수급자.2 일반수급자.3 일반수급자.4 일반수급자.5  \
# 0      시점  자치구별(1)  자치구별(2)      소계    0~4세    5~9세  10~14세  15~19세  20~24세
# 1    2012       합계       소계  188017    2817    5117   11478   19560    9447
# 2    2012       합계      종로구    3057      33      67     164     220      99
# 3    2012       합계       중구    3498      23      65     148     268     126
# 4    2012       합계      용산구    4284      63      87     193     268     119
# ..    ...      ...      ...     ...     ...     ...     ...     ...     ...
# 204  2019       합계      관악구   15835     150     392     664    1095     726
# 205  2019       합계      서초구    5846      63     251     295     461     254
# 206  2019       합계      강남구   12290     184     294     493     798     607
# 207  2019       합계      송파구   13123     176     484     813    1176     681
# 208  2019       합계      강동구   11277     115     357     599     938     476
#
# ...

# %%
주민등록
# Out:
#     동별(1)  동별(2)  성별(1)      2013  2013.1  2013.2  2013.3  2013.4  2013.5  \
# 0   동별(1)  동별(2)  성별(1)         계       계       계       계       계       계
# 1   동별(1)  동별(2)  성별(1)        소계    0~4세    5~9세  10~14세  15~19세  20~24세
# 2      합계     소계      계  10012712  412727  403818  495012  621096  683039
# 3      합계     소계     남자   4940393  211790  207919  257037  325512  345172
# 4      합계     소계     여자   5072319  200938  195899  237975  295584  337868
# ..    ...    ...    ...       ...     ...     ...     ...     ...     ...
# 75     합계    송파구     남자    323719   14976   15130   18889   22579   23101
# 76     합계    송파구     여자    338674   14128   14044   17576   21302   22301
# 77     합계    강동구      계    479184   20726   19748   24226   31539   33521
# 78     합계    강동구     남자    239131   10694   10291   12772   17016   17654
# 79     합계    강동구     여자    240053   10033    9457   11454   14524   15868
#
#     2013.6  ... 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18  \
# ...

# %%
장애인
# Out:
#     동별(1)  동별(2)    2012  2012.1  2012.2  2012.3  2012.4 2012.5 2012.6 2012.7  \
# 0   동별(1)  동별(2)      합계      합계      합계      합계      합계     합계     합계     합계
# 1   동별(1)  동별(2)      소계      소계      소계      지체      지체     지체    뇌병변    뇌병변
# 2   동별(1)  동별(2)       계      남자      여자       계      남자     여자      계     남자
# 3      합계     소계  407528  237538  169990  208074  118130  89944  45041  26877
# 4      합계    종로구    6905    4020    2885    3467    1897   1570    774    475
# 5      합계     중구    6296    3650    2646    3279    1794   1485    680    434
# 6      합계    용산구    9225    5301    3924    4679    2570   2109   1049    634
# 7      합계    성동구   12256    7164    5092    6531    3659   2872   1315    816
# 8      합계    광진구   13187    7768    5419    6836    3934   2902   1407    869
# 9      합계   동대문구   16584    9740    6844    8978    5095   3883   1724   1054
# 10     합계    중랑구   20563   12070    8493   11226    6399   4827   2087   1239
# ...
