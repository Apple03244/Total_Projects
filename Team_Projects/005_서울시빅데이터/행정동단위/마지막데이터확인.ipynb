# %%
import pandas as pd

# %% [markdown]
# 침수지역

# %%
침수지역=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\decisiontree\침수지역2022.csv")
침수지역=침수지역[["GU_NAME","ADM_NM","ADM_CD","ADM_CD_2"]]

# %%
인구밀도=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\decisiontree\서울시_행정동별_인구밀도_2023.csv")

# %% [markdown]
# 행정동 코드북

# %%
코드북=인구밀도[["구","행정동","행정구역코드"]].rename(columns={"구":"GU_NAME","행정동":"ADM_NM"})

# %%
코드북[코드북['행정구역코드'].isna()]
# Out:
#     GU_NAME ADM_NM  행정구역코드
# 359     강남구   개포3동     NaN

# %% [markdown]
# 경사도

# %%
경사도=pd.read_excel(r"C:\Users\SAMSUNG\Desktop\decisiontree\경사도.xlsx")
경사도=경사도[["ADM_NM","ADM_CD",'경사도']]

# %%
경사도["ADM_CD"].nunique()
# Out:
# 424

# %% [markdown]
# 수문암거제방

# %%
수문=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\가공된데이터\수문.csv")
암거=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\가공된데이터\암거.csv")
제방=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\가공된데이터\제방.csv")

# %%
수문
# Out:
#                                   UFID    DIVI    QUAL      SCLS      FMTA  \
# 0    100037612004C006184642d37557b45df  SUD001  SUQ000  C0062241  S2117964
# 1    100037709007C0061a755e376fd8e4145  SUD001  SUQ000  C0062241  S2117964
# 2    100037709015C0061b5ec725f7ec74170  SUD001  SUQ000  C0062241  S2117964
# 3    100037709005C006120c0eaa525aa4dd7  SUD001  SUQ000  C0062241  S2117964
# 4    100037608070C00613bddf0f80e014b52  SUD001  SUQ000  C0062241  S2113950
# ..                                 ...     ...     ...       ...       ...
# 846  100037705031C00617d8ef1cdcfe94d4e  SUD003  SUQ000  C0062243  S2116153
# 847  100037705041C00619f8899ad22644b6b  SUD003  SUQ000  C0062243  S2116153
# 848  100037705041C00619f8899ad22644b6b  SUD003  SUQ000  C0062243  S2116153
# 849  100037705041C00610b57fe1c96974a9f  SUD003  SUQ000  C0062243  S2116153
# 850  100037705041C00610b57fe1c96974a9f  SUD003  SUQ000  C0062243  S2116153
#
# ...
