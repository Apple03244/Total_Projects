# %%
import pandas as pd
import dbfread

# %%
file=dbfread.DBF(r"C:\Users\SAMSUNG\Desktop\공부파일들\서울시빅데이타\B422. 서울시 누적강수량(월평균) 공간데이터\2. 파일데이터\2016\RFL_AGE.dbf"
                 ,load=True,encoding='euc-kr')

# %%
pd.DataFrame(file)
# Out:
#                      LAYER            지점  M01   M02   M03   M04   M05   M06  \
# 0    Unknown Point Feature   [1151][서]남산  1.0  33.0  19.5  28.0  39.0  48.5
# 1    Unknown Point Feature  [1152][서]동대문  0.5  27.5  18.0  39.5  32.0  47.5
# 2    Unknown Point Feature   [1153][서]성북  NaN   1.0  20.0  32.5  37.5  55.5
# 3    Unknown Point Feature   [1154][서]도봉  0.0  46.5  22.0  37.5  33.5  57.0
# 4    Unknown Point Feature   [1155][서]마포  0.5  31.5  14.5  19.5  36.0  44.0
# ..                     ...           ...  ...   ...   ...   ...   ...   ...
# 435  Unknown Point Feature    [424][기]강북  0.0  26.0  48.0  33.0  43.0  23.0
# 436  Unknown Point Feature    [509][기]관악  0.0  19.5  35.0  28.5  46.5  37.5
# 437  Unknown Point Feature   [510][기]영등포  0.0  23.5  42.5  20.5  43.0  12.5
# 438  Unknown Point Feature    [425][기]남현  0.0  21.5  44.5  27.5  51.0  35.5
# 439  Unknown Point Feature   [889][기]현충원  0.0  20.0  33.0  29.0  40.5  26.5
#
# ...
