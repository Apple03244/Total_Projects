# %%
import pandas as pd
Data=pd.read_excel("../../더했다간미워할거야.xlsx")
data=pd.DataFrame(Data)

# %%
cols1=[x for x in Data.columns if x.find("만족도")!=-1]
cols2=["삶의 사다리 점수","성별","연령","교육수준","종교"]

# %%
data=data[cols1+cols2]

# %%
data=data.drop(columns=["성별","종교","연령"])

# %%
data.corr().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_9679a_row0_col0, #T_9679a_row1_col1, #T_9679a_row2_col2, #T_9679a_row3_col3, #T_9679a_row4_col4, #T_9679a_row5_col5, #T_9679a_row6_col6, #T_9679a_row7_col7, #T_9679a_row8_col8, #T_9679a_row9_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9679a_row0_col1, #T_9679a_row3_col1, #T_9679a_row3_col9, #T_9679a_row9_col0, #T_9679a_row9_col2, #T_9679a_row9_col3, #T_9679a_row9_col4, #T_9679a_row9_col5, #T_9679a_row9_col6, #T_9679a_row9_col7, #T_9679a_row9_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9679a_row0_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_9679a_row0_col3, #T_9679a_row5_col1, #T_9679a_row7_col0, #T_9679a_row9_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_9679a_row0_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_9679a_row0_col5, #T_9679a_row1_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_9679a_row0_col6 {
# ...
